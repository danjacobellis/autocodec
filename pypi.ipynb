# %%
# !rm -rf dist/

# %%
# !python3 -m build
# Out:
# * Creating virtualenv isolated environment...
# * Installing packages in isolated environment... (setuptools>=42, wheel)
# * Getting build dependencies for sdist...
# /tmp/build-env-9to1wn8k/lib/python3.10/site-packages/setuptools/config/expand.py:126: SetuptoolsWarning: File '/home/dgj335/danjacobellis/autocodec/LICENSE' cannot be found
#   return '\n'.join(
# running egg_info
# writing src/autocodec.egg-info/PKG-INFO
# writing dependency_links to src/autocodec.egg-info/dependency_links.txt
# writing requirements to src/autocodec.egg-info/requires.txt
# writing top-level names to src/autocodec.egg-info/top_level.txt
# reading manifest file 'src/autocodec.egg-info/SOURCES.txt'
# writing manifest file 'src/autocodec.egg-info/SOURCES.txt'
# * Building sdist...
# /tmp/build-env-9to1wn8k/lib/python3.10/site-packages/setuptools/config/expand.py:126: SetuptoolsWarning: File '/home/dgj335/danjacobellis/autocodec/LICENSE' cannot be found
#   return '\n'.join(
# running sdist
# ...

# %%
# !twine upload dist/*
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading autocodec-0.1.0-py3-none-any.whl
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 kB • 00:00 • ?
# Uploading autocodec-0.1.0.tar.gz
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 kB • 00:00 • ?
#
# View at:
# https://pypi.org/project/autocodec/0.1.0/

# %%
# !pip install --upgrade autocodec
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# ...
# Using cached triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.1 MB)
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
